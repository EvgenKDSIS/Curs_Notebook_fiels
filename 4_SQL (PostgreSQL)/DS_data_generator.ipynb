# %%
from faker import Faker
import random
import datetime

fake = Faker()

# Generate and print the CREATE TABLE statement
create_table_sql = """
CREATE TABLE grafana_data (
    id serial PRIMARY KEY,
    timestamp timestamp,
    category varchar(50),
    value float,
    region varchar(50),
    department varchar(50),
    product varchar(50),
    status varchar(20)
);
"""

print(create_table_sql)

# Generate and print the INSERT INTO statements
insert_statements = []
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
regions = ['North', 'South', 'East', 'West']
departments = ['Sales', 'Marketing', 'Finance', 'Operations']
products = ['Product A', 'Product B', 'Product C', 'Product D']
statuses = ['Pending', 'Processing', 'Completed']

for _ in range(200):
    timestamp = fake.date_time_this_year()
    category = random.choice(categories)
    value = round(random.uniform(10, 1000), 2)
    region = random.choice(regions)
    department = random.choice(departments)
    product = random.choice(products)
    status = random.choice(statuses)

    insert_statement = f"INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('{timestamp}', '{category}', {value}, '{region}', '{department}', '{product}', '{status}');"
    insert_statements.append(insert_statement)

for statement in insert_statements:
    print(statement)
# Out:
# CREATE TABLE grafana_data (
#     id serial PRIMARY KEY,
#     timestamp timestamp,
#     category varchar(50),
#     value float,
#     region varchar(50),
#     department varchar(50),
#     product varchar(50),
#     status varchar(20)
# );
#
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-17 00:55:20', 'Category C', 293.02, 'North', 'Marketing', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-28 16:34:44', 'Category B', 196.47, 'North', 'Sales', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-12 06:28:53', 'Category E', 698.69, 'East', 'Finance', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-13 17:49:03', 'Category C', 913.87, 'South', 'Marketing', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-13 13:36:42', 'Category C', 403.25, 'South', 'Operations', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-29 23:03:37', 'Category A', 384.91, 'West', 'Sales', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-15 10:54:53', 'Category D', 377.56, 'North', 'Sales', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-14 03:45:15', 'Category B', 349.33, 'South', 'Sales', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-31 10:08:40', 'Category D', 882.74, 'East', 'Operations', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-15 10:30:14', 'Category A', 586.33, 'West', 'Sales', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-11 16:34:24', 'Category A', 115.26, 'South', 'Sales', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-02 11:22:17', 'Category D', 148.1, 'North', 'Marketing', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-18 21:07:44', 'Category C', 538.9, 'North', 'Sales', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-07 03:46:55', 'Category B', 228.92, 'South', 'Sales', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-24 21:51:43', 'Category A', 214.95, 'East', 'Finance', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-03 08:16:19', 'Category B', 60.65, 'North', 'Finance', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-07 15:13:22', 'Category C', 28.78, 'North', 'Finance', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-03 08:33:19', 'Category E', 360.94, 'West', 'Finance', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-11 07:50:24', 'Category E', 199.68, 'North', 'Sales', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-05 20:55:59', 'Category B', 923.41, 'West', 'Sales', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-10 14:22:11', 'Category C', 811.28, 'North', 'Operations', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-27 23:49:56', 'Category D', 18.44, 'East', 'Sales', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-09 10:24:23', 'Category C', 890.43, 'South', 'Operations', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-02 20:11:21', 'Category C', 833.14, 'South', 'Sales', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-24 13:23:40', 'Category C', 913.53, 'North', 'Sales', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-31 02:09:39', 'Category A', 982.23, 'West', 'Operations', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-25 13:40:05', 'Category A', 97.85, 'South', 'Sales', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-18 17:24:14', 'Category D', 66.26, 'North', 'Sales', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-30 20:11:08', 'Category B', 437.22, 'North', 'Operations', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-18 02:48:29', 'Category E', 306.74, 'East', 'Finance', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-03 09:42:51', 'Category B', 605.18, 'North', 'Sales', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-24 03:17:43', 'Category B', 177.19, 'North', 'Sales', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-10 15:40:17', 'Category B', 851.97, 'East', 'Operations', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-12 19:36:38', 'Category C', 253.58, 'West', 'Operations', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-29 12:33:23', 'Category A', 807.72, 'North', 'Sales', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-20 18:03:34', 'Category C', 212.28, 'West', 'Finance', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-11 07:21:54', 'Category D', 183.52, 'South', 'Marketing', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-01 22:29:39', 'Category E', 388.28, 'West', 'Marketing', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-12 12:29:35', 'Category C', 898.28, 'South', 'Operations', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-07 05:22:56', 'Category C', 458.19, 'West', 'Finance', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-23 13:24:16', 'Category D', 32.42, 'North', 'Operations', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-23 06:35:36', 'Category A', 575.93, 'West', 'Finance', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-02 09:25:35', 'Category D', 468.19, 'East', 'Operations', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-04 17:05:03', 'Category A', 872.64, 'East', 'Finance', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-29 00:45:58', 'Category C', 939.76, 'East', 'Finance', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-30 21:14:39', 'Category D', 644.05, 'South', 'Operations', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-05 19:06:18', 'Category B', 400.33, 'West', 'Sales', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-12 07:45:06', 'Category A', 109.73, 'West', 'Marketing', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-09 07:48:02', 'Category D', 514.57, 'West', 'Sales', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-08 18:27:39', 'Category C', 703.46, 'South', 'Sales', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-27 21:02:13', 'Category E', 698.27, 'North', 'Marketing', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-21 11:14:42', 'Category E', 142.89, 'South', 'Sales', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-07 02:39:53', 'Category C', 12.32, 'West', 'Marketing', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-16 13:23:30', 'Category C', 594.02, 'North', 'Finance', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-09 15:51:10', 'Category D', 151.78, 'North', 'Sales', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-26 13:50:27', 'Category A', 83.5, 'West', 'Marketing', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-02 23:46:10', 'Category D', 648.48, 'North', 'Operations', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-23 11:30:03', 'Category E', 472.15, 'North', 'Marketing', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-08 09:42:22', 'Category B', 433.54, 'West', 'Operations', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-29 17:40:11', 'Category C', 258.53, 'North', 'Operations', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-30 12:06:13', 'Category A', 671.01, 'South', 'Sales', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-02 18:34:17', 'Category A', 305.1, 'North', 'Sales', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-26 11:55:50', 'Category D', 938.03, 'East', 'Finance', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-02 18:33:55', 'Category A', 294.37, 'South', 'Finance', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-10 05:27:39', 'Category B', 200.45, 'East', 'Finance', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-24 19:01:55', 'Category A', 856.32, 'West', 'Finance', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-19 17:31:24', 'Category A', 320.98, 'South', 'Marketing', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-03 14:00:28', 'Category E', 894.84, 'North', 'Marketing', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-19 03:57:10', 'Category E', 816.99, 'West', 'Operations', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-15 22:49:38', 'Category B', 217.27, 'West', 'Sales', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-27 14:27:36', 'Category B', 593.3, 'North', 'Sales', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-28 15:38:28', 'Category C', 62.35, 'West', 'Sales', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-19 10:25:56', 'Category E', 318.71, 'North', 'Operations', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-19 08:53:22', 'Category C', 169.33, 'South', 'Marketing', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-30 10:48:11', 'Category A', 767.91, 'South', 'Finance', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-22 20:04:55', 'Category B', 955.04, 'North', 'Operations', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-25 23:01:40', 'Category C', 392.76, 'East', 'Marketing', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-26 15:00:51', 'Category B', 748.91, 'East', 'Finance', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-07 09:51:05', 'Category A', 183.5, 'South', 'Sales', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-27 09:53:05', 'Category B', 66.77, 'North', 'Finance', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-26 09:00:45', 'Category E', 611.5, 'North', 'Marketing', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-15 05:43:27', 'Category E', 878.29, 'South', 'Sales', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-10 18:40:32', 'Category A', 806.74, 'West', 'Operations', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-27 21:59:42', 'Category C', 753.27, 'West', 'Finance', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-28 04:23:03', 'Category D', 944.02, 'East', 'Marketing', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-07 00:48:13', 'Category C', 82.25, 'East', 'Finance', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-28 21:13:36', 'Category A', 410.31, 'South', 'Operations', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-15 04:03:56', 'Category B', 738.09, 'North', 'Marketing', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-15 23:36:57', 'Category C', 202.81, 'South', 'Sales', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-22 00:33:16', 'Category E', 987.36, 'South', 'Finance', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-30 15:13:40', 'Category E', 916.4, 'South', 'Operations', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-02 16:27:44', 'Category B', 571.61, 'North', 'Finance', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-06 09:24:54', 'Category E', 891.36, 'West', 'Operations', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-20 16:39:06', 'Category A', 38.38, 'South', 'Finance', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-08 06:03:55', 'Category B', 319.34, 'North', 'Sales', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-28 07:06:37', 'Category B', 665.58, 'East', 'Marketing', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-22 22:21:43', 'Category B', 65.26, 'West', 'Sales', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-11 23:45:46', 'Category A', 490.12, 'East', 'Sales', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-27 19:38:08', 'Category E', 456.56, 'East', 'Sales', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-22 01:20:57', 'Category D', 524.11, 'West', 'Operations', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-12 05:25:57', 'Category E', 792.86, 'West', 'Sales', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-20 22:50:16', 'Category D', 267.06, 'East', 'Finance', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-03 10:05:48', 'Category A', 617.38, 'East', 'Marketing', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-22 17:00:33', 'Category D', 117.46, 'South', 'Marketing', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-28 02:52:45', 'Category B', 222.76, 'West', 'Operations', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-20 08:17:25', 'Category D', 513.46, 'South', 'Finance', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-04 04:15:30', 'Category C', 344.56, 'North', 'Operations', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-08 14:33:23', 'Category D', 872.98, 'South', 'Finance', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-30 13:06:52', 'Category C', 425.95, 'South', 'Sales', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-22 00:36:02', 'Category D', 902.54, 'North', 'Finance', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-08 08:05:41', 'Category A', 79.04, 'North', 'Operations', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-01 01:44:18', 'Category D', 844.09, 'West', 'Finance', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-02 22:51:25', 'Category C', 608.7, 'East', 'Finance', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-20 10:05:48', 'Category E', 966.51, 'North', 'Sales', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-29 05:03:56', 'Category D', 831.84, 'East', 'Marketing', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-29 21:32:32', 'Category E', 282.32, 'East', 'Operations', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-20 19:06:03', 'Category E', 307.73, 'East', 'Operations', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-03 11:35:48', 'Category E', 718.05, 'North', 'Marketing', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-01 20:30:23', 'Category D', 812.61, 'North', 'Operations', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-10 09:35:39', 'Category A', 729.08, 'South', 'Marketing', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-07 12:20:59', 'Category E', 270.71, 'South', 'Finance', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-25 05:20:28', 'Category C', 352.07, 'North', 'Finance', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-20 04:00:22', 'Category D', 345.58, 'East', 'Finance', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-09 23:57:44', 'Category B', 683.94, 'North', 'Finance', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-16 14:34:09', 'Category A', 968.71, 'East', 'Finance', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-08 14:51:19', 'Category B', 856.83, 'West', 'Finance', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-15 09:07:04', 'Category E', 544.22, 'West', 'Finance', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-03 06:39:17', 'Category B', 604.02, 'West', 'Finance', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-22 16:05:35', 'Category C', 365.91, 'North', 'Sales', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-20 23:50:24', 'Category C', 989.51, 'West', 'Sales', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-19 03:03:57', 'Category C', 790.18, 'North', 'Finance', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-26 21:19:52', 'Category A', 459.36, 'South', 'Finance', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-11 00:01:01', 'Category D', 747.12, 'North', 'Finance', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-02 09:58:44', 'Category A', 231.07, 'North', 'Finance', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-24 16:20:42', 'Category A', 185.25, 'South', 'Finance', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-28 01:36:15', 'Category B', 296.78, 'West', 'Sales', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-02 02:56:09', 'Category B', 679.08, 'East', 'Operations', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-30 21:49:26', 'Category D', 114.06, 'South', 'Sales', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-19 06:27:53', 'Category D', 73.23, 'South', 'Operations', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-10 10:24:39', 'Category B', 76.03, 'South', 'Sales', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-19 22:32:57', 'Category B', 89.99, 'East', 'Marketing', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-26 02:35:41', 'Category A', 818.05, 'East', 'Sales', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-09 04:24:03', 'Category B', 998.01, 'West', 'Sales', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-22 16:03:30', 'Category B', 560.34, 'East', 'Operations', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-18 18:22:59', 'Category D', 466.6, 'South', 'Sales', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-11 08:35:52', 'Category E', 745.49, 'West', 'Sales', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-17 07:52:01', 'Category A', 296.82, 'West', 'Operations', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-10 20:16:44', 'Category A', 121.66, 'East', 'Marketing', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-21 17:05:28', 'Category A', 26.92, 'West', 'Marketing', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-10 04:38:48', 'Category B', 354.42, 'East', 'Sales', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-26 09:31:46', 'Category E', 951.33, 'South', 'Sales', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-16 00:34:31', 'Category A', 316.59, 'South', 'Finance', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-31 16:48:07', 'Category D', 36.46, 'East', 'Finance', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-25 09:41:33', 'Category D', 287.63, 'South', 'Marketing', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-16 20:05:48', 'Category B', 59.46, 'West', 'Sales', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-01 14:27:02', 'Category D', 841.04, 'South', 'Finance', 'Product D', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-20 23:48:04', 'Category A', 967.63, 'East', 'Marketing', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-06 10:52:27', 'Category C', 908.04, 'North', 'Sales', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-11 03:07:43', 'Category B', 182.72, 'West', 'Marketing', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-16 23:25:04', 'Category E', 385.64, 'West', 'Operations', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-05 13:45:19', 'Category D', 426.91, 'East', 'Sales', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-30 12:23:55', 'Category B', 675.45, 'North', 'Finance', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-08 18:34:44', 'Category C', 469.6, 'East', 'Operations', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-24 02:44:58', 'Category E', 373.06, 'North', 'Operations', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-09 00:08:32', 'Category B', 24.4, 'West', 'Finance', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-11 14:04:44', 'Category E', 523.21, 'West', 'Operations', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-12 06:11:17', 'Category D', 499.36, 'East', 'Marketing', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-13 09:12:13', 'Category E', 628.54, 'North', 'Operations', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-08 15:40:36', 'Category C', 113.31, 'West', 'Operations', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-10 02:32:18', 'Category D', 203.71, 'West', 'Operations', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-02 19:58:58', 'Category C', 288.96, 'West', 'Marketing', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-16 04:52:03', 'Category B', 49.26, 'West', 'Finance', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-10 16:21:09', 'Category A', 942.09, 'North', 'Marketing', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-17 23:57:36', 'Category B', 796.57, 'South', 'Finance', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-09 21:17:55', 'Category A', 762.89, 'West', 'Finance', 'Product C', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-08 14:35:48', 'Category C', 842.75, 'South', 'Finance', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-27 01:01:06', 'Category A', 893.98, 'North', 'Operations', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-28 16:13:32', 'Category A', 790.07, 'East', 'Sales', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-02-27 19:16:27', 'Category E', 157.74, 'South', 'Operations', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-17 11:33:09', 'Category A', 843.0, 'North', 'Finance', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-22 16:51:14', 'Category D', 240.49, 'East', 'Operations', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-07 01:36:19', 'Category B', 863.65, 'South', 'Marketing', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-13 00:06:29', 'Category B', 159.24, 'West', 'Marketing', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-25 13:40:47', 'Category D', 544.21, 'North', 'Finance', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-19 20:56:48', 'Category D', 76.33, 'North', 'Operations', 'Product C', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-29 08:57:47', 'Category B', 498.44, 'East', 'Finance', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-02 10:54:57', 'Category D', 483.91, 'North', 'Operations', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-28 02:17:51', 'Category B', 837.65, 'West', 'Finance', 'Product A', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-06-02 14:33:53', 'Category D', 313.31, 'West', 'Sales', 'Product B', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-23 11:21:43', 'Category B', 737.6, 'North', 'Sales', 'Product B', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-09 12:00:32', 'Category C', 220.66, 'West', 'Finance', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-29 02:16:03', 'Category A', 864.5, 'East', 'Operations', 'Product D', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-16 08:45:49', 'Category D', 397.46, 'West', 'Marketing', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-01-07 08:25:17', 'Category D', 962.46, 'South', 'Sales', 'Product A', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-03-04 05:25:37', 'Category A', 383.57, 'South', 'Marketing', 'Product D', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-15 11:04:10', 'Category C', 925.9, 'East', 'Finance', 'Product B', 'Completed');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-04-03 00:32:45', 'Category E', 746.74, 'South', 'Sales', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-08-05 12:07:22', 'Category D', 336.36, 'East', 'Operations', 'Product A', 'Processing');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-05-09 20:14:57', 'Category A', 301.48, 'North', 'Finance', 'Product C', 'Pending');
# INSERT INTO grafana_data (timestamp, category, value, region, department, product, status) VALUES ('2023-07-27 13:33:00', 'Category C', 221.2, 'West', 'Operations', 'Product C', 'Completed');
